# %% [markdown]
# # Project 2

# %% [markdown]
# Dataset link - https://salaries.news.baltimoresun.com/static/csv/cy2017-md.csv

# %%
# importing the libraries needed for the EDA of the dataset

import pandas as pd
import csv
import numpy as np
import matplotlib.pyplot as plt

# %%
# importing the csv file into dataframe

data = pd.read_csv("https://salaries.news.baltimoresun.com/static/csv/cy2017-md.csv")

# %%
data
# Out:
#        first_name middle_initial  last_name suffix system    agency  \
# 0            JOHN              C     POLIKS    NaN     RG  290201.0
# 1       JOSEPHINE              K     OBONYO    NaN     RG  290201.0
# 2         DARLENE              M   BENEDICT    NaN     RG  290201.0
# 3            LORI              J   MCFARLIN    NaN     RG  290201.0
# 4          ELWOOD              D       HALL     JR     RG  290201.0
# ...           ...            ...        ...    ...    ...       ...
# 127835      EDDIE              L    JOHNSON    NaN     CT  500216.0
# 127836      JAMES            NaN   JENNINGS    NaN     CT  500216.0
# 127837  SYLVANITA              F  HENDRICKS    NaN     CT  500216.0
# 127838      GRANT            NaN     MAYHEW    NaN     CT  500220.0
# 127839                      NaN        NaN    NaN    NaN       NaN
#
#                         organization                       subtitle  \
# 0       DEPARTMENT OF TRANSPORTATION                         290201
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127840 entries, 0 to 127839
# Data columns (total 16 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   first_name          127839 non-null  object
#  1   middle_initial      103291 non-null  object
#  2   last_name           127834 non-null  object
#  3   suffix              3535 non-null    object
#  4   system              127839 non-null  object
#  5   agency              127839 non-null  float64
#  6   organization        127839 non-null  object
#  7   subtitle            127839 non-null  object
#  8   class_code          127839 non-null  float64
#  9   annual_salary       127839 non-null  float64
#  10  pay_rate            127839 non-null  object
#  11  regular_earnings    127839 non-null  float64
#  12  overtime_earnings   127839 non-null  float64
#  13  other_earnings      127839 non-null  float64
#  14  ytd_gross_earnings  127839 non-null  float64
# ...

# %%
data.describe()
# Out:
#               agency     class_code  annual_salary  regular_earnings  \
# count  127839.000000  127839.000000  127839.000000     127839.000000
# mean   335140.320004    4475.178991   40592.096309      42002.417103
# std     46323.554074    3193.777079   44375.964083      41120.725874
# min    210101.000000       0.000000       0.000000          0.000000
# 25%    320605.000000    1212.000000       0.000000       9000.000000
# 50%    360221.000000    4081.000000   41000.000000      39000.000000
# 75%    360225.000000    8200.000000   61000.000000      59000.000000
# max    500224.000000    9991.000000  922000.000000     858000.000000
#
#        overtime_earnings  other_earnings  ytd_gross_earnings
# count      127839.000000    1.278390e+05        1.278390e+05
# mean         1763.593270    1.458632e+03        4.523847e+04
# std          6417.418316    9.978953e+03        4.417802e+04
# min         -5000.000000   -1.700000e+04        0.000000e+00
# ...

# %%
# finding how many duplicate rows in the data

duplicate_rows_data = data[data.duplicated()]
print('number of duplicate rows: ', duplicate_rows_data.shape)
# Out:
# number of duplicate rows:  (1, 16)

# %%
# deleting duplicate rows

data = data.drop_duplicates()

# %%
data.count()
# Out:
# first_name            127838
# middle_initial        103290
# last_name             127833
# suffix                  3535
# system                127838
# agency                127838
# organization          127838
# subtitle              127838
# class_code            127838
# annual_salary         127838
# pay_rate              127838
# regular_earnings      127838
# overtime_earnings     127838
# other_earnings        127838
# ytd_gross_earnings    127838
# term_date             127838
# dtype: int64

# %%
# checking how many columns has null values

print (data.isnull().sum())
# Out:
# first_name                 1
# middle_initial         24549
# last_name                  6
# suffix                124304
# system                     1
# agency                     1
# organization               1
# subtitle                   1
# class_code                 1
# annual_salary              1
# pay_rate                   1
# regular_earnings           1
# overtime_earnings          1
# other_earnings             1
# ytd_gross_earnings         1
# term_date                  1
# dtype: int64

# %% [markdown]
# Only Middle Initial and suffix columns have the null values. Which seems okay because not everyone have that.
#
# So, we will fill 0 in the dataset.

# %%
#fill NAN values with 0

data = data.fillna(0)

# %%
#checking the sum of NAN vlaues after filling with 0

data.isnull().sum()
# Out:
# first_name            0
# middle_initial        0
# last_name             0
# suffix                0
# system                0
# agency                0
# organization          0
# subtitle              0
# class_code            0
# annual_salary         0
# pay_rate              0
# regular_earnings      0
# overtime_earnings     0
# other_earnings        0
# ytd_gross_earnings    0
# term_date             0
# dtype: int64

# %%
# We will plot a bar chart to know which organization has highest number of employees.

data.organization.value_counts().plot(kind='bar', figsize=(18,9))
plt.title("Number of employees by Organization")
plt.ylabel('Number of Employees')
plt.xlabel('Organization')
data.organization.value_counts()
# Out:
# UNIVERSITY OF MARYLAND            34668
# STATE UNIVERSITIES & COLLEGES     19152
# MARYLAND DEPARTMENT OF HEALTH     11778
# DEPARTMENT OF TRANSPORTATION       8663
# DEPT OF PUB SAFETY & COR SERVS     7894
#                                   ...
# DEPT OF NATURAL RESOURES             12
# MARYLAND TAX COURT                    9
# MD ST BRD OF CONTRACT APPEALS         6
# CANAL PLACE PRESERV & DEV AUTH        4
# 0                                     1
# Name: organization, Length: 75, dtype: int64

# %%
# scatterplot of annual salary 
plt.figure(figsize=(9,8))
plt.title("Scatterplot of Annual salary")
plt.ylabel('Amount')
plt.xlabel('Employees')
data['annual_salary'].plot()

# %% [markdown]
# # Employee with the highest annual salary

# %%
#checking who has the maximum salary
max_salary = data[data.annual_salary == data.annual_salary.max()] 
max_salary
# Out:
#       first_name middle_initial last_name suffix system    agency  \
# 73679    BRADLEY              S    TAYLOR      0     UM  360221.0
#
#                  organization    subtitle  class_code  annual_salary pay_rate  \
# 73679  UNIVERSITY OF MARYLAND  360221-UMB      1212.0       922000.0        A
#
#        regular_earnings  overtime_earnings  other_earnings  \
# 73679          544000.0                0.0             0.0
#
#        ytd_gross_earnings term_date
# 73679            544000.0         0

# %%
#displaying the top 5 employee with 'A' payrate

high = data[data['pay_rate'] == 'A']
high.head()
# Out:
#   first_name middle_initial last_name suffix system    agency  \
# 0       JOHN              C    POLIKS      0     RG  290201.0
# 1  JOSEPHINE              K    OBONYO      0     RG  290201.0
# 2    DARLENE              M  BENEDICT      0     RG  290201.0
# 3       LORI              J  MCFARLIN      0     RG  290201.0
# 4     ELWOOD              D      HALL     JR     RG  290201.0
#
#                    organization subtitle  class_code  annual_salary pay_rate  \
# 0  DEPARTMENT OF TRANSPORTATION   290201      8096.0        68000.0        A
# 1  DEPARTMENT OF TRANSPORTATION   290201      4849.0        64000.0        A
# 2  DEPARTMENT OF TRANSPORTATION   290201      4865.0            0.0        A
# 3  DEPARTMENT OF TRANSPORTATION   290201      7480.0        62000.0        A
# 4  DEPARTMENT OF TRANSPORTATION   290201      7890.0        43000.0        A
#
#    regular_earnings  overtime_earnings  other_earnings  ytd_gross_earnings  \
# ...

# %%
#displaying the lowest 5 employee with 'H' payrate

low = data[data['pay_rate'] == 'H']
low.tail()
# Out:
#        first_name middle_initial  last_name suffix system    agency  \
# 127834     HANNAH              0      SMITH      0     CT  500214.0
# 127835      EDDIE              L    JOHNSON      0     CT  500216.0
# 127836      JAMES              0   JENNINGS      0     CT  500216.0
# 127837  SYLVANITA              F  HENDRICKS      0     CT  500216.0
# 127838      GRANT              0     MAYHEW      0     CT  500220.0
#
#              organization                       subtitle  class_code  \
# 127834  REGISTER OF WILLS             500214 KENT COUNTY      9702.0
# 127835  REGISTER OF WILLS  500216 PRINCE GEORGE'S COUNTY      8990.0
# 127836  REGISTER OF WILLS  500216 PRINCE GEORGE'S COUNTY      8990.0
# 127837  REGISTER OF WILLS  500216 PRINCE GEORGE'S COUNTY      8990.0
# 127838  REGISTER OF WILLS           500220 TALBOT COUNTY      9702.0
#
#         annual_salary pay_rate  regular_earnings  overtime_earnings  \
# 127834            0.0        H           10000.0                0.0
# ...

# %%
import seaborn as sns

# %matplotlib inline

plt.style.use('bmh')

# %%
#See the statistics
print(data['annual_salary'].describe()) 

#Plot annual salary distribution
plt.figure(figsize=(9, 8))
plt.xlim(0,500000)
sns.distplot(data['annual_salary'], color='b', bins=100, hist_kws={'alpha': 0.4});
# Out:
# count    127839.000000
# mean      40592.096309
# std       44375.964083
# min           0.000000
# 25%           0.000000
# 50%       41000.000000
# 75%       61000.000000
# max      922000.000000
# Name: annual_salary, dtype: float64

# %%
#Gross salary is statistics
print(data['ytd_gross_earnings'].describe()) 

#plot ytd grosss salary
plt.figure(figsize=(9, 8))
plt.xlim(0,600000)
sns.distplot(data['ytd_gross_earnings'], color='b', bins=100, hist_kws={'alpha': .3});
# Out:
# count    1.278390e+05
# mean     4.523846e+04
# std      4.417803e+04
# min      0.000000e+00
# 25%      1.100000e+04
# 50%      4.100000e+04
# 75%      6.400000e+04
# max      2.720000e+06
# Name: ytd_gross_earnings, dtype: float64

# %%
plt.figure(figsize=(12,8))
c= data.corr()
sns.heatmap(c,cmap="RdBu_r",annot=True)
c
# Out:
#                       agency  class_code  annual_salary  regular_earnings  \
# agency              1.000000   -0.199708      -0.042019         -0.040493
# class_code         -0.199708    1.000000      -0.151186         -0.133207
# annual_salary      -0.042019   -0.151186       1.000000          0.924561
# regular_earnings   -0.040493   -0.133207       0.924561          1.000000
# overtime_earnings   0.068776    0.000443       0.054656          0.048005
# other_earnings      0.044712   -0.069974       0.094025          0.115443
# ytd_gross_earnings -0.017605   -0.139817       0.889563          0.963641
#
#                     overtime_earnings  other_earnings  ytd_gross_earnings
# agency                       0.068776        0.044712           -0.017605
# class_code                   0.000443       -0.069974           -0.139817
# annual_salary                0.054656        0.094025            0.889563
# regular_earnings             0.048005        0.115443            0.963641
# ...

# %% [markdown]
# This graph shows the correlation between the entities which have integer values.

# %% [markdown]
# We don't need agency and class_code in the correlation data.
#
# So, let's remove that and create a new list only containing the columns we need.

# %%
numbers = list(['annual_salary','regular_earnings','overtime_earnings','other_earnings','ytd_gross_earnings'])
plt.figure(figsize=(12,8))
z = data[numbers].corr()
sns.heatmap(z,cmap="BuPu",annot=True)
z
# Out:
#                     annual_salary  regular_earnings  overtime_earnings  \
# annual_salary            1.000000          0.924561           0.054656
# regular_earnings         0.924561          1.000000           0.048005
# overtime_earnings        0.054656          0.048005           1.000000
# other_earnings           0.094025          0.115443           0.005185
# ytd_gross_earnings       0.889563          0.963641           0.191216
#
#                     other_earnings  ytd_gross_earnings
# annual_salary             0.094025            0.889563
# regular_earnings          0.115443            0.963641
# overtime_earnings         0.005185            0.191216
# other_earnings            1.000000            0.333925
# ytd_gross_earnings        0.333925            1.000000

# %% [markdown]
# The removal of the columns from the data was learned from the mentioned link.
#
# https://stackoverflow.com/questions/42128462/in-python-how-to-do-correlation-between-multiple-columns-more-than-2-variables
