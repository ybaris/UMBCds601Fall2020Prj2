# %% [raw]
# link for the dataset
#
# 'https://data.boston.gov/dataset/03693648-2c62-4a2c-a4ec-48de2ee14e18/resource/4582bec6-2b4f-4f9e-bc55-cbaa73117f4c/download/tmpyf7ww55_.csv'

# %%
#importing libraries
import pandas as pd
import numpy as np
import time
import os
import sqlite3
import matplotlib.pyplot as plt
import matplotlib as mlp

# %%
#importing dataset
data = pd.read_csv("Boston_Restaurant.csv")
start_time = time.time()
print(time.time() - start_time, 'seconds')
# Out:
# c:\users\dhruv\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (23) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# 0.0 seconds

# %%
#checking memory of the dataset
data_file = "/Users/dhruv/Boston_Restaurant.csv"
data_memory = os.stat(data_file)
    
print(data_memory)
print(f'Bytes: {data_memory.st_size} Bytes')
print(f'MegaBytes: {data_memory.st_size / (1024 * 1024)} MB')
# Out:
# os.stat_result(st_mode=33206, st_ino=2533274790397960, st_dev=950186759, st_nlink=1, st_uid=0, st_gid=0, st_size=240113648, st_atime=1605490263, st_mtime=1602990160, st_ctime=1602990513)
# Bytes: 240113648 Bytes
# MegaBytes: 228.99021911621094 MB

# %%
#checking number of columns and rows of data
data.shape
# Out:
# (621489, 26)

# %%
data.info
# Out:
# <bound method DataFrame.info of                     businessname dbaname         legalowner namelast  \
# 0       100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# 1       100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# 2       100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# 3       100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# 4       100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# ...                          ...     ...                ...      ...
# 621484       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
# 621485       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
# 621486       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
# 621487       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
# 621488       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
#
#        namefirst  licenseno              issdttm              expdttm  \
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of                     businessname dbaname         legalowner namelast  \
# 0       100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# 1       100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# 2       100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# 3       100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# 4       100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# ...                          ...     ...                ...      ...
# 621484       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
# 621485       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
# 621486       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
# 621487       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
# 621488       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
#
#        namefirst  licenseno              issdttm              expdttm  \
# ...

# %%
#first 5 rows of the data
data.head()
# Out:
#                businessname dbaname         legalowner namelast namefirst  \
# 0  100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte   Civelis
# 1  100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte   Civelis
# 2  100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte   Civelis
# 3  100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte   Civelis
# 4  100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte   Civelis
#
#    licenseno              issdttm              expdttm licstatus licensecat  \
# 0      87059  2013-04-05 12:47:23  2020-12-31 23:59:00    Active         FS
# 1      87059  2013-04-05 12:47:23  2020-12-31 23:59:00    Active         FS
# 2      87059  2013-04-05 12:47:23  2020-12-31 23:59:00    Active         FS
# 3      87059  2013-04-05 12:47:23  2020-12-31 23:59:00    Active         FS
# 4      87059  2013-04-05 12:47:23  2020-12-31 23:59:00    Active         FS
#
#    ...             violdttm violstatus statusdate  \
# ...

# %%
#last 5 rows of the data
data.tail()
# Out:
#                businessname dbaname       legalowner namelast namefirst  \
# 621484  Zume's Coffee House     NaN  KERRIGAN ROBERT  Doherty      John
# 621485  Zume's Coffee House     NaN  KERRIGAN ROBERT  Doherty      John
# 621486  Zume's Coffee House     NaN  KERRIGAN ROBERT  Doherty      John
# 621487  Zume's Coffee House     NaN  KERRIGAN ROBERT  Doherty      John
# 621488  Zume's Coffee House     NaN  KERRIGAN ROBERT  Doherty      John
#
#         licenseno              issdttm              expdttm licstatus  \
# 621484      27260  2012-02-06 10:50:02  2020-12-31 23:59:00    Active
# 621485      27260  2012-02-06 10:50:02  2020-12-31 23:59:00    Active
# 621486      27260  2012-02-06 10:50:02  2020-12-31 23:59:00    Active
# 621487      27260  2012-02-06 10:50:02  2020-12-31 23:59:00    Active
# 621488      27260  2012-02-06 10:50:02  2020-12-31 23:59:00    Active
#
#        licensecat  ...             violdttm violstatus           statusdate  \
# ...

# %%
#vertical first 5 rows of the data
data.head().T
# Out:
#                                           0  \
# businessname       100 Percent Delicia Food
# dbaname                                 NaN
# legalowner                BRENNAN PATRICK E
# namelast                              Marte
# namefirst                           Civelis
# licenseno                             87059
# issdttm                 2013-04-05 12:47:23
# expdttm                 2020-12-31 23:59:00
# licstatus                            Active
# licensecat                               FS
# descript                  Eating & Drinking
# result                              HE_Fail
# resultdttm              2013-02-15 12:19:42
# violation                       15-4-202.16
# viollevel                                 *
# violdesc          Non-Food Contact Surfaces
# violdttm                2013-02-15 12:19:42
# violstatus                             Fail
# statusdate                              NaN
# comments        Provide glass storage rack.
# ...

# %%
#checking null values
total = data.isnull().sum().sort_values(ascending = False)
percent = (data.isnull().sum()/data.isnull().count()*100).sort_values(ascending = False)
missing_data  = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head()
# Out:
#               Total    Percent
# dbaname      615600  99.052437
# statusdate   362399  58.311410
# legalowner   193820  31.186393
# location     175629  28.259390
# property_id  134454  21.634172

# %%
#Checking how many different addresses we have
a= data['namelast'].nunique()
a
# Out:
# 6836

# %%
#Checking how many different owners are in dataset
b = data['legalowner'].nunique()
b
# Out:
# 2665

# %%
#average value of what one business owns
c = a/b
c
# Out:
# 2.5651031894934335

# %%
#checking type of license category
liccat = data.licensecat.unique()
liccat
# Out:
# array(['FS', 'RF', 'FT', 'MFW'], dtype=object)

# %%
#checking type of license category
licstat = data.licstatus.unique()
licstat
# Out:
# array(['Active', 'Inactive', 'Deleted'], dtype=object)

# %%
#Displaying license status with number and category
df = data[['namelast', 'licenseno', 'licensecat', 'licstatus']]
df
# Out:
#        namelast  licenseno licensecat licstatus
# 0         Marte      87059         FS    Active
# 1         Marte      87059         FS    Active
# 2         Marte      87059         FS    Active
# 3         Marte      87059         FS    Active
# 4         Marte      87059         FS    Active
# ...         ...        ...        ...       ...
# 621484  Doherty      27260         FT    Active
# 621485  Doherty      27260         FT    Active
# 621486  Doherty      27260         FT    Active
# 621487  Doherty      27260         FT    Active
# 621488  Doherty      27260         FT    Active
#
# [621489 rows x 4 columns]

# %%
#checking violation category
vio01 = data.violation.unique()
vio01
# Out:
# array(['15-4-202.16', '16-4-501.11/.15', '29-5-201/02.11',
#        '31-5-204/05.11', '37-6-501.11-.12', '05-4-302.12', '14-4-202.11',
#        '32-6-301.11-02.11', '36-6-501.11-.12', '08-3-302.11/3-304.11',
#        '08-3-305-307.11', '17-4-204.112/.115', '17-4-302.14',
#        '21-3-304.14', '33-5-501.13-.17', '38-6-303.11',
#        '02-3-602.11-.12/3-302.12', '23-4-602.13', '24-4-903.11',
#        '03-3-501.16', 'M-2-103.11', '03-3-501.14', '42-6-501.113/.114',
#        'M-2-102.11', '06-3-501.13', nan, '35-6-501.111/.115',
#        '36-6-201.11', '37-6-201.11', '590.004/4-204.112-C',
#        '01-3-602.11 B2', '590.003/3-304.14-C', '590.003/3-501.16-P',
#        '590.005/5-205.15-C', '590.005/5-501.17-C', '590.006/6-202.11-C',
#        '590.006/6-301.12-PF', '590.006/6-301.14-C', '590.006/6-501.114-C',
#        '590.002(C)/2-102.12-C', '590.004/4-301.11-PF',
#        '590.006/6-202.14-C', '590.006/6-501.11-C', '13-2-304/402.11',
# ...

# %%
#Checking levels of violation
vio02 = data.viollevel.unique()
vio02
# Out:
# array(['*', '***', nan, '**', '-', '1919', ' '], dtype=object)

# %%
#Checking status of violation
vio03 = data.violstatus.unique()
vio03
# Out:
# array(['Fail', nan, 'Pass', ' '], dtype=object)

# %%
#displaying the data with violation Fail status
vio03A = data[data['violstatus'] == 'Fail']
vio03A
# Out:
#                     businessname dbaname         legalowner namelast  \
# 0       100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# 1       100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# 2       100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# 3       100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# 4       100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# ...                          ...     ...                ...      ...
# 621432       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
# 621439       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
# 621440       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
# 621441       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
# 621444       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
#
#        namefirst  licenseno              issdttm              expdttm  \
# ...

# %%
#displaying the data with violation Pass Status
vio03B = data[data['violstatus'] == 'Pass']
vio03B
# Out:
#                     businessname dbaname         legalowner namelast  \
# 79      100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# 81      100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# 82      100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# 83      100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# 84      100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# ...                          ...     ...                ...      ...
# 621484       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
# 621485       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
# 621486       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
# 621487       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
# 621488       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
#
#        namefirst  licenseno              issdttm              expdttm  \
# ...

# %%
#displaying the data with blank Status
vio03C = data[data['violstatus'] == ' ']
vio03C
# Out:
#                businessname dbaname legalowner          namelast   namefirst  \
# 1161               24 SEVEN     NaN        NaN     24 SEVEN INC.
# 1212               24 SEVEN     NaN        NaN     24 SEVEN INC.
# 1213               24 SEVEN     NaN        NaN     24 SEVEN INC.
# 1214               24 SEVEN     NaN        NaN     24 SEVEN INC.
# 1215               24 SEVEN     NaN        NaN     24 SEVEN INC.
# ...                     ...     ...        ...               ...         ...
# 620735  Zumas Tex-Mex Grill     NaN        NaN  B B Kitchen Inc.  Cody Baker
# 621016  Zumas Tex-Mex Grill     NaN        NaN  B B Kitchen Inc.  Cody Baker
# 621017  Zumas Tex-Mex Grill     NaN        NaN  B B Kitchen Inc.  Cody Baker
# 621018  Zumas Tex-Mex Grill     NaN        NaN  B B Kitchen Inc.  Cody Baker
# 621027  Zumas Tex-Mex Grill     NaN        NaN  B B Kitchen Inc.  Cody Baker
#
#         licenseno              issdttm              expdttm licstatus  \
# ...

# %%
#dropping the rows where the violation status is blank
data02 = data.drop(data[data['violstatus'] == ' '].index)

# %%
#checking shape of the data
print(data02.shape)
# Out:
# (615754, 26)

# %%
data02.head().T
# Out:
#                                           0  \
# businessname       100 Percent Delicia Food
# dbaname                                 NaN
# legalowner                BRENNAN PATRICK E
# namelast                              Marte
# namefirst                           Civelis
# licenseno                             87059
# issdttm                 2013-04-05 12:47:23
# expdttm                 2020-12-31 23:59:00
# licstatus                            Active
# licensecat                               FS
# descript                  Eating & Drinking
# result                              HE_Fail
# resultdttm              2013-02-15 12:19:42
# violation                       15-4-202.16
# viollevel                                 *
# violdesc          Non-Food Contact Surfaces
# violdttm                2013-02-15 12:19:42
# violstatus                             Fail
# statusdate                              NaN
# comments        Provide glass storage rack.
# ...

# %%
#Coverted comments column into list
cmmnts = data02['comments'].values.tolist()
cmmnts
# Out:
# ['Provide glass storage rack.',
#  'Provide dish rack over 3 bay sink to replace missing drainboards at each end of  3 bay sink.',
#  'Provide dish washer at ware washing area.',
#  'Provide mop sink at basement.',
#  'No hand sink at Bar Area  provide.',
#  'Provide door and finish miscellaneous storage room.',
#  'Provide dish washer at ware washing area.',
#  'Provide chefs thermometer for monitoring food temperatures.',
#  'Replace heavily scorded cutting board.',
#  'Dishmachine not operating  repair.',
#  'Provide sink plugs for sink behind service bar.',
#  'Provide dispenser for paper towels.',
#  'Exhausthood sticker not visible  provide current documentation on exhausthood cleaning.',
#  'Repair loose pipe below hand sink behind beverage bar.',
#  'Replace missing floor tiles at entrance to kitchen.',
#  'Paint wall for storage.',
#  'Observed raw chicken stored over ready to eat product.Provide proper storage of raw and ready to eat products.',
# ...

# %%
#Displaying 1 star violation level
violevel01 = data02[data02['viollevel'] == '*']
violevel01
# Out:
#                     businessname dbaname         legalowner namelast  \
# 0       100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# 1       100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# 2       100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# 3       100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# 5       100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# ...                          ...     ...                ...      ...
# 621472       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
# 621473       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
# 621474       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
# 621475       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
# 621486       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
#
#        namefirst  licenseno              issdttm              expdttm  \
# ...

# %%
#Displaying 2 star violation level
violevel02 = data02[data02['viollevel'] == '**']
violevel02
# Out:
#                         businessname dbaname         legalowner  \
# 75          100 Percent Delicia Food     NaN  BRENNAN PATRICK E
# 143         100 Percent Delicia Food     NaN  BRENNAN PATRICK E
# 182     100 Percent Delicias Express     NaN  STAMATOS GEORGE C
# 186     100 Percent Delicias Express     NaN  STAMATOS GEORGE C
# 203     100 Percent Delicias Express     NaN  STAMATOS GEORGE C
# ...                              ...     ...                ...
# 621483           Zume's Coffee House     NaN    KERRIGAN ROBERT
# 621484           Zume's Coffee House     NaN    KERRIGAN ROBERT
# 621485           Zume's Coffee House     NaN    KERRIGAN ROBERT
# 621487           Zume's Coffee House     NaN    KERRIGAN ROBERT
# 621488           Zume's Coffee House     NaN    KERRIGAN ROBERT
#
#                                 namelast     namefirst  licenseno  \
# 75                                 Marte       Civelis      87059
# ...

# %%
#Displaying 3 star violation level
violevel03 = data02[data02['viollevel'] == '***']
violevel03
# Out:
#                     businessname dbaname         legalowner namelast  \
# 4       100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# 16      100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# 30      100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# 36      100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# 41      100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# ...                          ...     ...                ...      ...
# 621469       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
# 621471       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
# 621476       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
# 621480       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
# 621482       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
#
#        namefirst  licenseno              issdttm              expdttm  \
# ...

# %%
#Displaying nan value violation level
violevel04 = data02[data02['viollevel'] == 'nan']
violevel04
# Out:
# Empty DataFrame
# Columns: [businessname, dbaname, legalowner, namelast, namefirst, licenseno, issdttm, expdttm, licstatus, licensecat, descript, result, resultdttm, violation, viollevel, violdesc, violdttm, violstatus, statusdate, comments, address, city, state, zip, property_id, location]
# Index: []
#
# [0 rows x 26 columns]

# %%
#Displaying '-' violation level
violevel05 = data02[data02['viollevel'] == '-']
violevel05
# Out:
#                          businessname dbaname  \
# 55197                        BK's Pub     NaN
# 55211                        BK's Pub     NaN
# 129755            Cold Stone Creamery     NaN
# 129783            Cold Stone Creamery     NaN
# 177525                 DUNKIN DONUTS'     NaN
# 177653                 DUNKIN DONUTS'     NaN
# 256665                  Hometown Poke     NaN
# 256669                  Hometown Poke     NaN
# 263882                        I-CE-NY     NaN
# 263922                        I-CE-NY     NaN
# 277182              Jamaica Mi Hungry     NaN
# 277190              Jamaica Mi Hungry     NaN
# 277202              Jamaica Mi Hungry     NaN
# 380196  Niva Dowtown Boston Gift Shop     NaN
# 380205  Niva Dowtown Boston Gift Shop     NaN
# 383516         Nouria Logan No. 04000     NaN
# 383521         Nouria Logan No. 04000     NaN
# 385140               Oath Craft Pizza     NaN
# 385151               Oath Craft Pizza     NaN
# ...

# %%
#Displaying nan value violation level
violevel06 = data02[data02['viollevel'] == '1919']
violevel06
# Out:
# Empty DataFrame
# Columns: [businessname, dbaname, legalowner, namelast, namefirst, licenseno, issdttm, expdttm, licstatus, licensecat, descript, result, resultdttm, violation, viollevel, violdesc, violdttm, violstatus, statusdate, comments, address, city, state, zip, property_id, location]
# Index: []
#
# [0 rows x 26 columns]

# %%
#Displaying nan value violation level
violevel07 = data02[data02['viollevel'] == ' ']
violevel07
# Out:
#              businessname dbaname        legalowner namelast namefirst  \
# 301833  LA SULTANA BAKERY     NaN  FAUSTINO SANCHEZ  SANCHEZ    Amelia
#
#         licenseno              issdttm              expdttm licstatus  \
# 301833      19921  2012-03-06 09:35:43  2020-12-31 23:59:00    Active
#
#        licensecat  ...             violdttm violstatus           statusdate  \
# 301833         FT  ...  2009-07-09 08:11:26       Pass  2009-07-09 08:11:26
#
#                                                  comments           address  \
# 301833  label all bulk food containers to identify pro...  40   MAVERICK SQ
#
#                city state    zip property_id location
# 301833  EAST BOSTON    MA  02128         NaN      NaN
#
# [1 rows x 26 columns]

# %%
#Checking shape of 1 star violation
violevel01.shape
# Out:
# (434477, 26)

# %%
#Checking shape of 2 star violation
violevel02.shape
# Out:
# (46174, 26)

# %%
#Checking shape of 3 star violation
violevel03.shape
# Out:
# (100569, 26)

# %%
#Checking shape of nan value violation
violevel04.shape
# Out:
# (0, 26)

# %%
#Checking shape of '-' violation
violevel05.shape
# Out:
# (40, 26)

# %%
#Checking shape of 1919 violation
violevel06.shape
# Out:
# (0, 26)

# %%
#Checking shape of ' ' blank violation
violevel07.shape
# Out:
# (1, 26)

# %%
#plotting pie chart for violation status
data02.viollevel.value_counts().plot(kind='pie', autopct='%1.1f%%', figsize=(20,12))
plt.title("PieChart of Violation status")

#1 star is 74.7%
#2 star is 7.9%
#3 star is 17.3%
#nan value is 0.0%
# Out:
# Text(0.5, 1.0, 'PieChart of Violation status')

# %%
#creating dummy variables of violstatus column
dummy = pd.get_dummies(data02['violstatus'])
dummy
# Out:
#         Fail  Pass
# 0          1     0
# 1          1     0
# 2          1     0
# 3          1     0
# 4          1     0
# ...      ...   ...
# 621484     0     1
# 621485     0     1
# 621486     0     1
# 621487     0     1
# 621488     0     1
#
# [615754 rows x 2 columns]

# %%
#concatinating fail and passinthe dataset
data02 = pd.concat((data02, dummy), axis = 1)
data02
# Out:
#                     businessname dbaname         legalowner namelast  \
# 0       100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# 1       100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# 2       100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# 3       100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# 4       100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# ...                          ...     ...                ...      ...
# 621484       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
# 621485       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
# 621486       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
# 621487       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
# 621488       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
#
#        namefirst  licenseno              issdttm              expdttm  \
# ...

# %%
data02.head().T
# Out:
#                                           0  \
# businessname       100 Percent Delicia Food
# dbaname                                 NaN
# legalowner                BRENNAN PATRICK E
# namelast                              Marte
# namefirst                           Civelis
# licenseno                             87059
# issdttm                 2013-04-05 12:47:23
# expdttm                 2020-12-31 23:59:00
# licstatus                            Active
# licensecat                               FS
# descript                  Eating & Drinking
# result                              HE_Fail
# resultdttm              2013-02-15 12:19:42
# violation                       15-4-202.16
# viollevel                                 *
# violdesc          Non-Food Contact Surfaces
# violdttm                2013-02-15 12:19:42
# violstatus                             Fail
# statusdate                              NaN
# comments        Provide glass storage rack.
# ...

# %%
#checking number of resturant city wise availablein dataset
city = data02.city.value_counts()
city
# Out:
# Boston                         232834
# Dorchester                      61495
# BOSTON                          53298
# Roxbury                         43912
# East Boston                     30328
# Jamaica Plain                   26103
# Allston                         18628
# DORCHESTER                      17187
# Brighton                        15473
# West Roxbury                    15323
# Roslindale                      14486
# South Boston                    13922
# EAST BOSTON                      9543
# Hyde Park                        8621
# Mattapan                         8574
# Charlestown                      7277
# Mission Hill                     7116
# ROXBURY                          6167
# SOUTH BOSTON                     4794
# ALLSTON                          4311
# BRIGHTON                         2759
# ROSLINDALE                       2175
# JAMAICA PLAIN                    2055
# MATTAPAN                         1999
# WEST ROXBURY                     1613
# ...

# %%
#plotting city column
data02.city.value_counts().plot(kind='bar', figsize=(18,9))
plt.title("Number of Restaurant by City")
plt.ylabel('Number of Restaurant')
plt.xlabel('City')
# Out:
# Text(0.5, 0, 'City')

# %%
#checking number of resturant city wise availablein dataset
state = data02.state.value_counts()
state
# Out:
# MA    603270
# Ma     10905
#         1175
# ma       404
# Name: state, dtype: int64

# %%
#plotting city column
data02.state.value_counts().plot(kind='bar', figsize=(18,9))
plt.title("Number of State")
plt.ylabel('Number of State')
plt.xlabel('State')
# Out:
# Text(0.5, 0, 'State')

# %%
#checking types of results
result = data02.result.unique()
result
# Out:
# array(['HE_Fail', 'HE_Pass', 'HE_FailExt', 'HE_NotReq', 'HE_Filed',
#        'HE_Hearing', 'HE_OutBus', 'HE_TSOP', 'HE_Hold', 'Pass',
#        'HE_VolClos', 'HE_Closure', 'DATAERR', 'HE_FAILNOR', 'HE_Misc',
#        'Fail', 'Failed', 'Closed', 'PassViol'], dtype=object)

# %%
#Converting violdec column into list
violdesc = data02['violdesc'].values.tolist()
violdesc
# Out:
# ['Non-Food Contact Surfaces',
#  'Dishwashng Facilities',
#  'Dishwashng Facilities',
#  'Installed and Maintained',
#  'Location  Accessible',
#  'Improper Maintenance of Walls/Ceilings',
#  'Dishwashng Facilities',
#  'Food Thermometers Provided',
#  'Food Contact Surfaces Design',
#  'Dishwashng Facilities',
#  'Dishwashng Facilities',
#  'Hand Cleaner  Drying  Tissue Signage',
#  'Improper Maintenance of Walls/Ceilings',
#  'Installed and Maintained',
#  'Improper Maintenance of Floors',
#  'Improper Maintenance of Walls/Ceilings',
#  'Separation  Segregation Cross Contamination',
#  'Food Protection',
#  'Food Protection',
#  'Equipment Thermometers',
#  'Test Kit Provided',
#  'Wiping Cloths  Clean  Sanitize',
#  'Installed and Maintained',
#  'Installed and Maintained',
#  'Installed and Maintained',
#  'Hand Cleaner  Drying  Tissue Signage',
#  'Adequate Number  Frequency Vermin Proof',
#  'Improper Maintenance of Walls/Ceilings',
#  'Inadequate Lighting',
# ...

# %%
#Displaying businessname, city, violation with Fail status, violation description, comments
df3 = data02[['businessname', 'city', 'Fail', 'violdesc', 'comments']]
df3
# Out:
#                     businessname         city  Fail  \
# 0       100 Percent Delicia Food   Roslindale     1
# 1       100 Percent Delicia Food   Roslindale     1
# 2       100 Percent Delicia Food   Roslindale     1
# 3       100 Percent Delicia Food   Roslindale     1
# 4       100 Percent Delicia Food   Roslindale     1
# ...                          ...          ...   ...
# 621484       Zume's Coffee House  Charlestown     0
# 621485       Zume's Coffee House  Charlestown     0
# 621486       Zume's Coffee House  Charlestown     0
# 621487       Zume's Coffee House  Charlestown     0
# 621488       Zume's Coffee House  Charlestown     0
#
#                                                  violdesc  \
# 0                               Non-Food Contact Surfaces
# 1                                   Dishwashng Facilities
# 2                                   Dishwashng Facilities
# 3                                Installed and Maintained
# ...

# %%
#cleaned dataset is ready
data02
# Out:
#                     businessname dbaname         legalowner namelast  \
# 0       100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# 1       100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# 2       100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# 3       100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# 4       100 Percent Delicia Food     NaN  BRENNAN PATRICK E    Marte
# ...                          ...     ...                ...      ...
# 621484       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
# 621485       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
# 621486       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
# 621487       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
# 621488       Zume's Coffee House     NaN    KERRIGAN ROBERT  Doherty
#
#        namefirst  licenseno              issdttm              expdttm  \
# ...
